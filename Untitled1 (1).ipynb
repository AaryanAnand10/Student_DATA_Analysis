# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import warnings
d = pd.read_csv(r"C:\Users\HP\Downloads\student_ml_dataset (1).csv")
warnings.filterwarnings('ignore')
d.head()
# Out:
#                 Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0        Derek Smith   26  Female       6.596347   98             68
# 1  Christopher Boyle   37    Male       5.672202  133             44
# 2      Bradley Jones   19    Male       6.282581   89             90
# 3      Eric Martinez   21    Male       8.004422  106             81
# 4   Jennifer Ferrell   29  Female       4.322501   88             41
#
#    Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 0         100               43               True
# 1          53               92               True
# 2          48               57               True
# 3          88               41              False
# 4          83               85               True

# %%
d.head(6)
# Out:
#                 Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0        Derek Smith   26  Female       6.596347   98             68
# 1  Christopher Boyle   37    Male       5.672202  133             44
# 2      Bradley Jones   19    Male       6.282581   89             90
# 3      Eric Martinez   21    Male       8.004422  106             81
# 4   Jennifer Ferrell   29  Female       4.322501   88             41
# 5        Ryan Rangel   40    Male       1.854121  119             58
#
#    Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 0         100               43               True
# 1          53               92               True
# 2          48               57               True
# 3          88               41              False
# 4          83               85               True
# 5         100               69               True

# %%
d.tail()
# Out:
#                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 995      Jonathan Long   29  Female       4.525427  100             64
# 996     Michael Morgan   34  Female       9.049785  129             70
# 997   Jacob Cunningham   29    Male       5.942553  108             68
# 998  Brittany Matthews   39  Female       5.268965  120             73
# 999      Daniel Kramer   28  Female       9.840650  106             74
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 995          72               63              False
# 996          91               40              False
# 997         100               98               True
# 998          52               87              False
# 999          82               55               True

# %%
d.sample(5)
# Out:
#                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 127     John Carpenter   29  Female       8.380407  136             59
# 538          Mark Reed   18  Female       4.122292   90             55
# 144         Julia Lang   40  Female       3.932093  144             40
# 96   Jennifer Thompson   26  Female       8.523082  104             44
# 825         Lisa Rojas   33  Female       7.427144  148             78
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 127          59               91              False
# 538          79               55               True
# 144          86               97               True
# 96           83              100              False
# 825          73               58               True

# %%
print("Number odcolumns",d.shape[0])
print("Number if rows",d.shape[1])
# Out:
# Number odcolumns 1000
# Number if rows 9

# %%
d.isnull()
# Out:
#       Name    Age  Gender  Hours_Studied     IQ  Physics_Marks  Math_Marks  \
# 0    False  False   False          False  False          False       False
# 1    False  False   False          False  False          False       False
# 2    False  False   False          False  False          False       False
# 3    False  False   False          False  False          False       False
# 4    False  False   False          False  False          False       False
# ..     ...    ...     ...            ...    ...            ...         ...
# 995  False  False   False          False  False          False       False
# 996  False  False   False          False  False          False       False
# 997  False  False   False          False  False          False       False
# 998  False  False   False          False  False          False       False
# 999  False  False   False          False  False          False       False
#
#      Chemistry_Marks  Has_Part_Time_Job
# 0              False              False
# 1              False              False
# 2              False              False
# 3              False              False
# 4              False              False
# ..               ...                ...
# 995            False              False
# 996            False              False
# 997            False              False
# 998            False              False
# 999            False              False
#
# [1000 rows x 9 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   object
#  1   Age                1000 non-null   int64
#  2   Gender             1000 non-null   object
#  3   Hours_Studied      1000 non-null   float64
#  4   IQ                 1000 non-null   int64
#  5   Physics_Marks      1000 non-null   int64
#  6   Math_Marks         1000 non-null   int64
#  7   Chemistry_Marks    1000 non-null   int64
#  8   Has_Part_Time_Job  1000 non-null   bool
# dtypes: bool(1), float64(1), int64(5), object(2)
# memory usage: 63.6+ KB

# %%
d.describe()
# Out:
#                Age  Hours_Studied           IQ  Physics_Marks   Math_Marks  \
# count  1000.000000    1000.000000  1000.000000    1000.000000  1000.000000
# mean     31.470000       5.394825   115.025000      69.585000    70.546000
# std       8.100909       2.555895    19.740721      17.357248    17.097199
# min      18.000000       1.003158    80.000000      40.000000    40.000000
# 25%      25.000000       3.188172    99.000000      54.000000    56.000000
# 50%      31.000000       5.466678   115.000000      70.000000    72.000000
# 75%      39.000000       7.462535   131.000000      84.000000    84.000000
# max      45.000000       9.997769   150.000000     100.000000   100.000000
#
#        Chemistry_Marks
# count      1000.000000
# mean         70.727000
# std          17.138909
# min          40.000000
# 25%          56.000000
# 50%          71.000000
# 75%          85.000000
# max         100.000000

# %%
cat=[]
num=[]
for column in d.columns:
    if d[column].nunique() > 199 :
        num.append(column)
    else:
        cat.append(column)

# %%
print(cat)
# Out:
# ['Age', 'Gender', 'IQ', 'Physics_Marks', 'Math_Marks', 'Chemistry_Marks', 'Has_Part_Time_Job']

# %%
print(num)
# Out:
# ['Name', 'Hours_Studied']

# %%
sns.countplot(d['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
d['Age'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
d['IQ'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.distplot(d['IQ'])
# Out:
# <Axes: xlabel='IQ', ylabel='Density'>

# %%
d['IQ'].skew()
# Out:
# -0.02530398875919914

# %%
d['Age'].skew()
# Out:
# 0.020055324860841675

# %%
sns.distplot(d['Physics_Marks'])
# Out:
# <Axes: xlabel='Physics_Marks', ylabel='Density'>

# %%
sns.distplot(d['Math_Marks'])
# Out:
# <Axes: xlabel='Math_Marks', ylabel='Density'>

# %%
sns.distplot(d['Chemistry_Marks'])
# Out:
# <Axes: xlabel='Chemistry_Marks', ylabel='Density'>

# %%
d['Math_Marks'].skew()
# Out:
# -0.07657920592997142

# %%
d['Physics_Marks'].skew()
# Out:
# -0.006835266849150355

# %%
d['Chemistry_Marks'].skew()
# Out:
# -0.03767523404088224

# %%
sns.boxplot(d['IQ'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=d['IQ'],y=d['Age'])
# Out:
# <Axes: xlabel='IQ', ylabel='Age'>

# %%
sns.scatterplot(x=d['IQ'],y=d['Hours_Studied'])
# Out:
# <Axes: xlabel='IQ', ylabel='Hours_Studied'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1759, in categorical_order(vector, order)
#    1758 try:
# -> 1759     order = vector.cat.categories
#    1760 except (TypeError, AttributeError):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1763, in categorical_order(vector, order)
#    1762 try:
# -> 1763     order = vector.unique()
#    1764 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 sns.barplot(x=d.values, y=d.index, alpha=0.8)
#
# File D:\Anaconda\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File D:\Anaconda\Lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File D:\Anaconda\Lib\site-packages\seaborn\categorical.py:591, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     588     group_label = groups.name
#     590 # Get the order on the categorical axis
# --> 591 group_names = categorical_order(groups, order)
#     593 # Group the numeric data
#     594 plot_data, value_label = self._group_longform(vals, groups,
#     595                                               group_names)
#
# File D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1765, in categorical_order(vector, order)
#    1763     order = vector.unique()
#    1764 except AttributeError:
# -> 1765     order = pd.unique(vector)
#    1767 if variable_type(vector) == "numeric":
#    1768     order = np.sort(order)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\algorithms.py:409, in unique(values)
#     315 def unique(values):
#     316     """
#     317     Return unique values based on a hash table.
#     318
#    (...)
#     407     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     408     """
# --> 409     return unique_with_mask(values)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\algorithms.py:425, in unique_with_mask(values, mask)
#     423 table = htable(len(values))
#     424 if mask is None:
# --> 425     uniques = table.unique(values)
#     426     uniques = _reconstruct_data(uniques, original.dtype, original)
#     427     return uniques
#
# File pandas\_libs\hashtable_class_helper.pxi:5888, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)
